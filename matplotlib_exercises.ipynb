# %% [markdown]
# 1.Use matplotlib to plot the following equation:
#             y=x**2−x+2
# You'll need to write the code that generates the x and y points.
# Add an anotation for the point 0, 0, the origin.

# %%
import matplotlib.pyplot as plt
x = range(-100, 100)
y = [(n**2 - n + 2) for n in x]
plt.plot(x, y)
plt.show()

# %% [markdown]
# 2.Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
# y=√x
# y=x**3 y = [n ** 2 for n in x]
# y=2**x
# y=1/(x+1)
# You can use functions from the math module to help implement some of the equations above.

# %%
import numpy as np
import math

x = range(1, 100)
y = np.sqrt(x)
plt.plot(x, y)
plt.show()

x = range(-100,100)
y = [n ** 3 for n in x]
plt.plot(x, y)
plt.show()

x = range(-100, 100)
y = [2**n for n in x]
plt.plot(x, y)
plt.show()

x = np.linspace(-10, 10, 100)
y = 1/(x+1)
plt.plot(x, y)
plt.show()

# %% [markdown]
# 3.Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.subplot(2, 2, 1)
x = range(1, 100)
y = np.sqrt(x)
plt.plot(x, y)


plt.subplot(2, 2, 2)
x = range(-100,100)
y = [n ** 3 for n in x]
plt.plot(x, y)



plt.subplot(2, 2, 3)
x = range(-100, 100)
y = [2**n for n in x]
plt.plot(x, y)



plt.subplot(2, 2, 4)
x = np.linspace(-10, 10, 100)
y = 1/(x+1)
plt.plot(x, y)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# First plot (Square root)
x1 = range(1, 100)
y1 = np.sqrt(x1)

# Second plot (Cubed)
x2 = range(-100, 100)
y2 = [n ** 3 for n in x2]

# Third plot (Exponential)
x3 = range(-100, 100)
y3 = [2 ** n for n in x3]

# Fourth plot (Rational function)
x4 = np.linspace(-10, 10, 100)
y4 = 1 / (x4 + 1)

# Create subplots
fig, ax = plt.subplots(2, 2, figsize=(12, 8))

# Plot the data on each subplot
ax[0, 0].plot(x1, y1)
ax[0, 0].set_title("Square Root")

ax[0, 1].plot(x2, y2)
ax[0, 1].set_title("Cubed")

ax[1, 0].plot(x3, y3)
ax[1, 0].set_title("Exponential")

ax[1, 1].plot(x4, y4)
ax[1, 1].set_title("Rational Function")

# Show the combined figure
plt.show()

# %% [markdown]
# 4.Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points.
# Be sure to include a legend and an appropriate title for the figure.

# %% [markdown]
# 5.Make a new Jupyter notebook named big_o_notation.ipynb
#     Title your chart "Big O Notation"
#     Label your x axis "Elements"
#     Label your y axis "Operations"
#     Label your curves or make a legend for the curves
#     Use LaTex notation where possible
# Curves to graph
# y=0n+1 and label the curve "O(1)"
# y=log(n) and label the curve "O(log n)"
# y=n and label the curve "O(n)"
# y=n∗log(n) and label it "O(n log n)"
# y=n2 and label it "O(n^2)"
# y=2n and label it "O(2^n)"
# y=n!and label it "O(n!)"
# y=n**n and label it "O(n^n)"

# %%
import numpy as np
import matplotlib.pyplot as plt

# First plot (Square root)
x1 = range(1, 5)
y1 = np.sqrt(x1)

# Second plot (Cubed)
x2 = range(-10, 10)
y2 = [n ** 3 for n in x2]

# Third plot (Exponential)
x3 = range(-10, 10)
y3 = [2 ** n for n in x3]

# Fourth plot (Rational function)
x4 = np.linspace(-1, 1, 10)
y4 = 1 / (x4 + 1)

# Create a single figure
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the data with different colors
ax.plot(x1, y1, label="Square Root", color="blue")
ax.plot(x2, y2, label="Cubed", color="green")
ax.plot(x3, y3, label="Exponential", color="red")
ax.plot(x4, y4, label="Rational Function", color="purple")

# Set title and legend
ax.set_title("Combined Plot of Four Functions")
ax.legend()

# Show the combined figure
plt.show()
# Out:
# /var/folders/xz/80c64x6n7gz157jssrv1zmj00000gn/T/ipykernel_12012/579738209.py:18: RuntimeWarning: divide by zero encountered in divide
#   y4 = 1 / (x4 + 1)

# %% [markdown]
# Bonus Write the code necessary to write your name on a chart. Use box letters.
#
# Bonus: use curves for letters in your name that have curves in them.
